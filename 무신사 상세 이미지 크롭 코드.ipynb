# %%
import cv2
import numpy as np
import requests
from PIL import Image
from io import BytesIO
import os
import pandas as pd

def load_image_from_url(url):
    try:
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        image = Image.open(BytesIO(response.content)).convert('RGB')
        return np.array(image)
    except requests.RequestException as e:
        print(f"Error loading image from URL: {e}")
        return None

def read_urls_from_csv(csv_file):
    try:
        df = pd.read_csv(csv_file)
        urls_by_folder = {}
        for index, row in df.iterrows():
            folder_name = f'{index}_{row[0]}'  # Combine row index and first column value
            urls_by_folder[folder_name] = []
            for url_string in row[1:].dropna():  # Skip the first column (folder name)
                split_urls = [url.strip() for url in url_string.split(',')]
                urls_by_folder[folder_name].extend(split_urls)
        
        return urls_by_folder
    except Exception as e:
        print(f"Error reading CSV file: {e}")
        return {}

def detect_edges(image):
    gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)
    edges = cv2.Canny(blurred_image, 50, 150)
    return edges

def find_boundaries(edges):
    row_boundaries = []
    previous_row_sum = np.sum(edges[0, :])
    for i in range(1, edges.shape[0]):
        current_row_sum = np.sum(edges[i, :])

        if previous_row_sum == 0 and current_row_sum > 0:
            row_boundaries.append(i)
        
        previous_row_sum = current_row_sum

    row_boundaries.append(edges.shape[0])
    return row_boundaries

def process_image(url, output_folder, image_index):
    image = load_image_from_url(url)
    if image is None:
        print(f"Skipping URL due to image load failure: {url}")
        return

    edges = detect_edges(image)
    row_boundaries = find_boundaries(edges)

    if len(row_boundaries) <= 1:
        # 경계선이 발견되지 않은 경우 원본 이미지를 저장
        output_path = os.path.join(output_folder, f'image_{image_index}.png')
        cv2.imwrite(output_path, cv2.cvtColor(image, cv2.COLOR_RGB2BGR))
        print(f'Saved original image to {output_path}')
    else:
        # 경계선이 있는 경우, 경계선 사이의 이미지 조각을 저장
        for k in range(1, len(row_boundaries)):
            if row_boundaries[k] - row_boundaries[k-1] > 500:
                cropped_image = image[row_boundaries[k-1]:row_boundaries[k], :]
                output_path = os.path.join(output_folder, f'image_{image_index}_row_crop_{k}.png')
                cv2.imwrite(output_path, cv2.cvtColor(cropped_image, cv2.COLOR_RGB2BGR))
                print(f'Saved cropped image to {output_path}')

def main(csv_file):
    if not os.path.isfile(csv_file):
        print(f"CSV file does not exist: {csv_file}")
        return

    urls_by_folder = read_urls_from_csv(csv_file)
    if not urls_by_folder:
        print("No URLs to process. Exiting.")
        return
    
    common_output_folder = os.path.join(os.path.expanduser("~"), 'cropped_images')
    os.makedirs(common_output_folder, exist_ok=True)

    for folder_name, urls in urls_by_folder.items():
        output_folder = os.path.join(common_output_folder, folder_name)
        os.makedirs(output_folder, exist_ok=True)

        for image_index, url in enumerate(urls, start=1):
            process_image(url, output_folder, image_index)

# CSV 파일 경로를 입력하세요 (절대 경로 사용)
csv_file_path = '/Users/nyeong/Downloads/상세이미지 크롤링.csv'

# 메인 함수 실행
main(csv_file_path)
# Out:
# /var/folders/xj/fzvk72k965q3qmw45xy3s80m0000gn/T/ipykernel_8501/1087288675.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   folder_name = f'{index}_{row[0]}'  # Combine row index and first column value
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_1_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_4_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_4_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_4_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_4_row_crop_12.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_4_row_crop_14.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_6_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_6_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_6_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_6_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_6_row_crop_11.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_8_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_8_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_8_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_8_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_9_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_9_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_9_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_9_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/0_스웨트셔츠 [블랙]/image_10_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/1_980G 피그먼트 맨투맨-챠콜-/image_3_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/1_980G 피그먼트 맨투맨-챠콜-/image_3_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/1_980G 피그먼트 맨투맨-챠콜-/image_3_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/1_980G 피그먼트 맨투맨-챠콜-/image_3_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/1_980G 피그먼트 맨투맨-챠콜-/image_3_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/1_980G 피그먼트 맨투맨-챠콜-/image_3_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/1_980G 피그먼트 맨투맨-챠콜-/image_4_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/1_980G 피그먼트 맨투맨-챠콜-/image_4_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/1_980G 피그먼트 맨투맨-챠콜-/image_4_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/1_980G 피그먼트 맨투맨-챠콜-/image_4_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/1_980G 피그먼트 맨투맨-챠콜-/image_4_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/1_980G 피그먼트 맨투맨-챠콜-/image_4_row_crop_9.png
# Saved cropped image to /Users/nyeong/cropped_images/1_980G 피그먼트 맨투맨-챠콜-/image_4_row_crop_10.png
# Saved cropped image to /Users/nyeong/cropped_images/1_980G 피그먼트 맨투맨-챠콜-/image_4_row_crop_12.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_1_row_crop_8.png
# Saved original image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_2.png
# Saved original image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_3.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_4_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_4_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_4_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_5_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_5_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_5_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_5_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_5_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_5_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_5_row_crop_9.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_6_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_6_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_6_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_7_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_7_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_7_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_8_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_8_row_crop_11.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_9_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_9_row_crop_12.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_9_row_crop_18.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_9_row_crop_20.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_9_row_crop_24.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_9_row_crop_30.png
# Saved original image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_10.png
# Saved original image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_11.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_12_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_12_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_12_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_13_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_13_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_13_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_14_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_14_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_14_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_14_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_15_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_15_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_16_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_16_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_16_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_17_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_17_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_17_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_17_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_17_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_17_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_18_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_18_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_19_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_19_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_20_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_20_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_20_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_21_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_21_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_21_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_21_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_21_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_21_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_21_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_22_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_22_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_22_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_23_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_23_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_23_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_24_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_24_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_24_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_25_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_25_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_25_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_26_row_crop_30.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_26_row_crop_31.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_26_row_crop_38.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_26_row_crop_39.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_26_row_crop_46.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_26_row_crop_47.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_26_row_crop_48.png
# Saved cropped image to /Users/nyeong/cropped_images/2_[2PACK] 유니)C/P기모쭈리 - LOCATION 맨투맨(세미오버핏)(15COLOR)[LRAWCTM704M/712M, 304M, GMT501H43]/image_26_row_crop_49.png
# Saved original image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_1.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_2_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_2_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_2_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_2_row_crop_14.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_2_row_crop_15.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_2_row_crop_16.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_2_row_crop_17.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_2_row_crop_18.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_2_row_crop_20.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_2_row_crop_21.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_3_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_3_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_3_row_crop_15.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_3_row_crop_16.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_3_row_crop_17.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_3_row_crop_18.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_3_row_crop_19.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_3_row_crop_20.png
# Saved cropped image to /Users/nyeong/cropped_images/3_헤비 코튼 오버 럭비 맨투맨_Midnight Blue/image_3_row_crop_21.png
# Saved cropped image to /Users/nyeong/cropped_images/4_베츠 어센틱 맨투맨 그레이/image_2_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/4_베츠 어센틱 맨투맨 그레이/image_3_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/4_베츠 어센틱 맨투맨 그레이/image_4_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/4_베츠 어센틱 맨투맨 그레이/image_4_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/4_베츠 어센틱 맨투맨 그레이/image_4_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/5_캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우/image_1_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/5_캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우/image_1_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/5_캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우/image_1_row_crop_10.png
# Saved cropped image to /Users/nyeong/cropped_images/5_캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우/image_1_row_crop_14.png
# Saved cropped image to /Users/nyeong/cropped_images/5_캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우/image_1_row_crop_18.png
# Saved cropped image to /Users/nyeong/cropped_images/5_캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우/image_1_row_crop_23.png
# Saved cropped image to /Users/nyeong/cropped_images/5_캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우/image_1_row_crop_28.png
# Saved cropped image to /Users/nyeong/cropped_images/5_캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우/image_1_row_crop_32.png
# Saved cropped image to /Users/nyeong/cropped_images/5_캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우/image_1_row_crop_35.png
# Saved cropped image to /Users/nyeong/cropped_images/5_캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우/image_1_row_crop_38.png
# Saved cropped image to /Users/nyeong/cropped_images/5_캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우/image_1_row_crop_41.png
# Saved cropped image to /Users/nyeong/cropped_images/5_캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우/image_1_row_crop_45.png
# Saved cropped image to /Users/nyeong/cropped_images/5_캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우/image_1_row_crop_47.png
# Saved cropped image to /Users/nyeong/cropped_images/5_캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우/image_1_row_crop_62.png
# Saved cropped image to /Users/nyeong/cropped_images/5_캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우/image_1_row_crop_72.png
# Saved cropped image to /Users/nyeong/cropped_images/5_캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우/image_1_row_crop_73.png
# Saved cropped image to /Users/nyeong/cropped_images/6_1960 sweatshirts navy/image_1_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/6_1960 sweatshirts navy/image_1_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/6_1960 sweatshirts navy/image_1_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/6_1960 sweatshirts navy/image_1_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/6_1960 sweatshirts navy/image_1_row_crop_10.png
# Saved cropped image to /Users/nyeong/cropped_images/6_1960 sweatshirts navy/image_1_row_crop_12.png
# Saved cropped image to /Users/nyeong/cropped_images/6_1960 sweatshirts navy/image_1_row_crop_14.png
# Saved cropped image to /Users/nyeong/cropped_images/6_1960 sweatshirts navy/image_1_row_crop_16.png
# Saved cropped image to /Users/nyeong/cropped_images/6_1960 sweatshirts navy/image_1_row_crop_18.png
# Saved cropped image to /Users/nyeong/cropped_images/6_1960 sweatshirts navy/image_1_row_crop_21.png
# Saved cropped image to /Users/nyeong/cropped_images/6_1960 sweatshirts navy/image_1_row_crop_27.png
# Saved cropped image to /Users/nyeong/cropped_images/6_1960 sweatshirts navy/image_2_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/6_1960 sweatshirts navy/image_2_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/6_1960 sweatshirts navy/image_2_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/6_1960 sweatshirts navy/image_2_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/6_1960 sweatshirts navy/image_2_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/6_1960 sweatshirts navy/image_2_row_crop_9.png
# Saved cropped image to /Users/nyeong/cropped_images/6_1960 sweatshirts navy/image_2_row_crop_11.png
# Saved cropped image to /Users/nyeong/cropped_images/7_LOCATION CREWNECK [INDIGO BLUE]/image_1_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/7_LOCATION CREWNECK [INDIGO BLUE]/image_2_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/7_LOCATION CREWNECK [INDIGO BLUE]/image_2_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/7_LOCATION CREWNECK [INDIGO BLUE]/image_2_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/7_LOCATION CREWNECK [INDIGO BLUE]/image_2_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/7_LOCATION CREWNECK [INDIGO BLUE]/image_2_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/7_LOCATION CREWNECK [INDIGO BLUE]/image_2_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/7_LOCATION CREWNECK [INDIGO BLUE]/image_2_row_crop_9.png
# Saved cropped image to /Users/nyeong/cropped_images/7_LOCATION CREWNECK [INDIGO BLUE]/image_2_row_crop_12.png
# Saved cropped image to /Users/nyeong/cropped_images/7_LOCATION CREWNECK [INDIGO BLUE]/image_2_row_crop_13.png
# Saved cropped image to /Users/nyeong/cropped_images/7_LOCATION CREWNECK [INDIGO BLUE]/image_2_row_crop_14.png
# Saved cropped image to /Users/nyeong/cropped_images/7_LOCATION CREWNECK [INDIGO BLUE]/image_2_row_crop_15.png
# Saved cropped image to /Users/nyeong/cropped_images/8_LOCATION CREWNECK [BLACK]/image_1_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/8_LOCATION CREWNECK [BLACK]/image_2_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/8_LOCATION CREWNECK [BLACK]/image_2_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/8_LOCATION CREWNECK [BLACK]/image_2_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/8_LOCATION CREWNECK [BLACK]/image_2_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/8_LOCATION CREWNECK [BLACK]/image_2_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/8_LOCATION CREWNECK [BLACK]/image_2_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/8_LOCATION CREWNECK [BLACK]/image_2_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/8_LOCATION CREWNECK [BLACK]/image_2_row_crop_10.png
# Saved cropped image to /Users/nyeong/cropped_images/8_LOCATION CREWNECK [BLACK]/image_2_row_crop_11.png
# Saved cropped image to /Users/nyeong/cropped_images/8_LOCATION CREWNECK [BLACK]/image_2_row_crop_12.png
# Saved cropped image to /Users/nyeong/cropped_images/8_LOCATION CREWNECK [BLACK]/image_2_row_crop_13.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_1_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_3_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_3_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_4_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_4_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_4_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_5_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_5_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_5_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_6_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_6_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_6_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_7_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_7_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_7_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_7_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_8_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_8_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_8_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_9_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_9_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_9_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_10_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_10_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_10_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_11_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_11_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_11_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_12_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_12_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_12_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_14_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_14_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_14_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_14_row_crop_6.png
# Saved original image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_15.png
# Saved original image to /Users/nyeong/cropped_images/9_로코 피그먼트 리버시블 헤비 맨투맨 (9 color)/image_17.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_9.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_12.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_15.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_17.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_20.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_23.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_26.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_29.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_32.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_34.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_37.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_40.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_43.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_46.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_49.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_51.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_54.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_57.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_60.png
# Saved cropped image to /Users/nyeong/cropped_images/10_[3-PACK]베이직 트래블러 피그먼트 스웨트셔츠/image_1_row_crop_63.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_1_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_1_row_crop_31.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_3_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_3_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_3_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_3_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_3_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_3_row_crop_10.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_3_row_crop_12.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_3_row_crop_13.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_3_row_crop_15.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_4_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_4_row_crop_13.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_4_row_crop_19.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_4_row_crop_25.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_4_row_crop_31.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_4_row_crop_37.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_4_row_crop_43.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_5_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_5_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_5_row_crop_14.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_5_row_crop_19.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_5_row_crop_24.png
# Saved cropped image to /Users/nyeong/cropped_images/11_[2PACK] Errday 루즈핏 맨투맨 2`nd/image_5_row_crop_29.png
# Saved original image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_2_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_2_row_crop_24.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_3_row_crop_5.png
# Saved original image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_6.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_7_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_8_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_9_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_10_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_11_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_12_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_13_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_14_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_15_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_16_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_17_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_18_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_19_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_20_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_21_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_22_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_23_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_24_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_25_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_26_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_27_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_28_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_29_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_30_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_31_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_32_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_33_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_34_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_35_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_36_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_37_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_38_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_40_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_41_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_42_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_43_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_44_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_45_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_46_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_47_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_48_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_49_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_49_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_49_row_crop_9.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_49_row_crop_19.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_49_row_crop_21.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_49_row_crop_27.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_49_row_crop_30.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_50_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_50_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_50_row_crop_9.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_50_row_crop_12.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_50_row_crop_19.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_50_row_crop_21.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_50_row_crop_27.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_50_row_crop_30.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_51_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_51_row_crop_5.png
# Saved original image to /Users/nyeong/cropped_images/12_[2PACK] 헤이즈 오버핏 스웨트셔츠 [쭈리/기모] 2PACK KJMT2369 / KJMT2400/image_52.png
# Saved cropped image to /Users/nyeong/cropped_images/13_[23SS] C 로고 맨투맨 블랙/image_1_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/13_[23SS] C 로고 맨투맨 블랙/image_2_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/13_[23SS] C 로고 맨투맨 블랙/image_2_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/13_[23SS] C 로고 맨투맨 블랙/image_3_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/13_[23SS] C 로고 맨투맨 블랙/image_3_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/13_[23SS] C 로고 맨투맨 블랙/image_3_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/13_[23SS] C 로고 맨투맨 블랙/image_3_row_crop_11.png
# Saved cropped image to /Users/nyeong/cropped_images/13_[23SS] C 로고 맨투맨 블랙/image_4_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/13_[23SS] C 로고 맨투맨 블랙/image_4_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/13_[23SS] C 로고 맨투맨 블랙/image_4_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_1_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_4_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_4_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_4_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_4_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_6_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_6_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_6_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_6_row_crop_9.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_6_row_crop_15.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_8_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_8_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_8_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_8_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_9_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_9_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_9_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_9_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/14_스웨트셔츠 [멜란지 그레이]/image_10_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/15_Half Zip-Up M-Logo Sweat (JP5TSU839MG)/image_1_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/15_Half Zip-Up M-Logo Sweat (JP5TSU839MG)/image_2_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/15_Half Zip-Up M-Logo Sweat (JP5TSU839MG)/image_3_row_crop_7.png
# Saved original image to /Users/nyeong/cropped_images/15_Half Zip-Up M-Logo Sweat (JP5TSU839MG)/image_4.png
# Saved cropped image to /Users/nyeong/cropped_images/15_Half Zip-Up M-Logo Sweat (JP5TSU839MG)/image_5_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/15_Half Zip-Up M-Logo Sweat (JP5TSU839MG)/image_5_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/15_Half Zip-Up M-Logo Sweat (JP5TSU839MG)/image_5_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/15_Half Zip-Up M-Logo Sweat (JP5TSU839MG)/image_5_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/15_Half Zip-Up M-Logo Sweat (JP5TSU839MG)/image_5_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/15_Half Zip-Up M-Logo Sweat (JP5TSU839MG)/image_5_row_crop_9.png
# Saved cropped image to /Users/nyeong/cropped_images/15_Half Zip-Up M-Logo Sweat (JP5TSU839MG)/image_5_row_crop_10.png
# Saved cropped image to /Users/nyeong/cropped_images/16_[23SS] C 로고 맨투맨 네이비/image_1_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/16_[23SS] C 로고 맨투맨 네이비/image_2_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/16_[23SS] C 로고 맨투맨 네이비/image_2_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/16_[23SS] C 로고 맨투맨 네이비/image_3_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/16_[23SS] C 로고 맨투맨 네이비/image_3_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/16_[23SS] C 로고 맨투맨 네이비/image_3_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/16_[23SS] C 로고 맨투맨 네이비/image_3_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/16_[23SS] C 로고 맨투맨 네이비/image_4_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/16_[23SS] C 로고 맨투맨 네이비/image_4_row_crop_3.png
# ...
# Saved cropped image to /Users/nyeong/cropped_images/1492_헤비 케이블 니트 울 스웨터 [네이비]/image_5_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/1492_헤비 케이블 니트 울 스웨터 [네이비]/image_6_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_1_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_1_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_1_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_1_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_1_row_crop_9.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_1_row_crop_11.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_1_row_crop_12.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_1_row_crop_13.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_1_row_crop_15.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_1_row_crop_16.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_1_row_crop_17.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_1_row_crop_18.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_1_row_crop_19.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_2_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_2_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_2_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_2_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_2_row_crop_11.png
# Saved cropped image to /Users/nyeong/cropped_images/1493_드로잉 플라워 니트 네이비/image_2_row_crop_13.png
# Saved cropped image to /Users/nyeong/cropped_images/1494_TORNADO LOGO KNIT_IVORY(NG2DFUK607A)/image_2_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/1494_TORNADO LOGO KNIT_IVORY(NG2DFUK607A)/image_2_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/1494_TORNADO LOGO KNIT_IVORY(NG2DFUK607A)/image_2_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/1494_TORNADO LOGO KNIT_IVORY(NG2DFUK607A)/image_2_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/1494_TORNADO LOGO KNIT_IVORY(NG2DFUK607A)/image_3_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/1494_TORNADO LOGO KNIT_IVORY(NG2DFUK607A)/image_3_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/1494_TORNADO LOGO KNIT_IVORY(NG2DFUK607A)/image_3_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/1494_TORNADO LOGO KNIT_IVORY(NG2DFUK607A)/image_3_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/1494_TORNADO LOGO KNIT_IVORY(NG2DFUK607A)/image_4_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_2_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_2_row_crop_16.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_2_row_crop_17.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_2_row_crop_18.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_2_row_crop_19.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_2_row_crop_20.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_2_row_crop_23.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_2_row_crop_24.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_2_row_crop_25.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_3_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_3_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_3_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_3_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_3_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_3_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_3_row_crop_9.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_4_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_4_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_4_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_4_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_4_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_4_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_4_row_crop_11.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_4_row_crop_12.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_4_row_crop_13.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_4_row_crop_14.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_4_row_crop_15.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_5_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_5_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_5_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_5_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_7_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_7_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_7_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_8_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_8_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/1495_Half Patchwork Knitwear KHAKI/image_8_row_crop_12.png
# Saved cropped image to /Users/nyeong/cropped_images/1496_후드 니트 (민트)/image_1_row_crop_1.png
# Saved cropped image to /Users/nyeong/cropped_images/1496_후드 니트 (민트)/image_1_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/1496_후드 니트 (민트)/image_1_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/1496_후드 니트 (민트)/image_1_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/1496_후드 니트 (민트)/image_1_row_crop_18.png
# Saved cropped image to /Users/nyeong/cropped_images/1496_후드 니트 (민트)/image_1_row_crop_19.png
# Saved cropped image to /Users/nyeong/cropped_images/1496_후드 니트 (민트)/image_1_row_crop_21.png
# Saved cropped image to /Users/nyeong/cropped_images/1496_후드 니트 (민트)/image_1_row_crop_22.png
# Saved cropped image to /Users/nyeong/cropped_images/1496_후드 니트 (민트)/image_1_row_crop_23.png
# Saved cropped image to /Users/nyeong/cropped_images/1496_후드 니트 (민트)/image_1_row_crop_25.png
# Saved cropped image to /Users/nyeong/cropped_images/1496_후드 니트 (민트)/image_1_row_crop_27.png
# Saved cropped image to /Users/nyeong/cropped_images/1496_후드 니트 (민트)/image_1_row_crop_28.png
# Saved cropped image to /Users/nyeong/cropped_images/1496_후드 니트 (민트)/image_1_row_crop_30.png
# Saved cropped image to /Users/nyeong/cropped_images/1496_후드 니트 (민트)/image_1_row_crop_31.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_1_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_1_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_1_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_1_row_crop_15.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_2_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_2_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_2_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_2_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_2_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_2_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_3_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_3_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_3_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_3_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_3_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_3_row_crop_9.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_4_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_4_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_4_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_4_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_4_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_4_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_5_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_5_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_5_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_5_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_5_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_5_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_6_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_6_row_crop_3.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_6_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_6_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_6_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_6_row_crop_9.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_7_row_crop_15.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_7_row_crop_35.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_7_row_crop_36.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_7_row_crop_39.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_7_row_crop_42.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_7_row_crop_45.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_7_row_crop_48.png
# Saved cropped image to /Users/nyeong/cropped_images/1497_[S/S 프레젠테이션]워셔블 투 톤 크루넥 그래픽 니트 (BEIGE)/image_7_row_crop_51.png
# Saved cropped image to /Users/nyeong/cropped_images/1498_램스울 크루넥 오버 니트 (애플레드)/image_1_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/1498_램스울 크루넥 오버 니트 (애플레드)/image_1_row_crop_33.png
# Saved cropped image to /Users/nyeong/cropped_images/1498_램스울 크루넥 오버 니트 (애플레드)/image_1_row_crop_34.png
# Saved cropped image to /Users/nyeong/cropped_images/1498_램스울 크루넥 오버 니트 (애플레드)/image_1_row_crop_35.png
# Saved cropped image to /Users/nyeong/cropped_images/1498_램스울 크루넥 오버 니트 (애플레드)/image_1_row_crop_36.png
# Saved cropped image to /Users/nyeong/cropped_images/1498_램스울 크루넥 오버 니트 (애플레드)/image_1_row_crop_37.png
# Saved cropped image to /Users/nyeong/cropped_images/1498_램스울 크루넥 오버 니트 (애플레드)/image_1_row_crop_38.png
# Saved cropped image to /Users/nyeong/cropped_images/1499_헨리넥 니트 티셔츠 [CREAM]/image_1_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/1499_헨리넥 니트 티셔츠 [CREAM]/image_1_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/1499_헨리넥 니트 티셔츠 [CREAM]/image_1_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/1499_헨리넥 니트 티셔츠 [CREAM]/image_1_row_crop_7.png
# Saved cropped image to /Users/nyeong/cropped_images/1499_헨리넥 니트 티셔츠 [CREAM]/image_1_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/1499_헨리넥 니트 티셔츠 [CREAM]/image_2_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/1499_헨리넥 니트 티셔츠 [CREAM]/image_2_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/1499_헨리넥 니트 티셔츠 [CREAM]/image_2_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/1499_헨리넥 니트 티셔츠 [CREAM]/image_2_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/1499_헨리넥 니트 티셔츠 [CREAM]/image_2_row_crop_9.png
# Saved cropped image to /Users/nyeong/cropped_images/1499_헨리넥 니트 티셔츠 [CREAM]/image_2_row_crop_11.png
# Saved cropped image to /Users/nyeong/cropped_images/1499_헨리넥 니트 티셔츠 [CREAM]/image_2_row_crop_13.png
# Saved cropped image to /Users/nyeong/cropped_images/1499_헨리넥 니트 티셔츠 [CREAM]/image_3_row_crop_2.png
# Saved cropped image to /Users/nyeong/cropped_images/1499_헨리넥 니트 티셔츠 [CREAM]/image_3_row_crop_4.png
# Saved cropped image to /Users/nyeong/cropped_images/1499_헨리넥 니트 티셔츠 [CREAM]/image_3_row_crop_5.png
# Saved cropped image to /Users/nyeong/cropped_images/1499_헨리넥 니트 티셔츠 [CREAM]/image_3_row_crop_6.png
# Saved cropped image to /Users/nyeong/cropped_images/1499_헨리넥 니트 티셔츠 [CREAM]/image_3_row_crop_8.png
# Saved cropped image to /Users/nyeong/cropped_images/1499_헨리넥 니트 티셔츠 [CREAM]/image_3_row_crop_10.png
